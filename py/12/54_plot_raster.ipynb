# %% [markdown]
# Ref: https://github.com/giswqs/leafmap/blob/master/examples/notebooks/54_plot_raster.ipynb
# https://twitter.com/giswqs/status/1542940704074338305?t=arYIwZg4UQE44qw9XC4TLg&s=09
#
# #Leafmap new feature - Visualizing elevation data in 3D in a #Jupyter environment with only one line of code. Built upon pyvista-xarray
# @banesullivan
#
# @rabernat
#
#
# Notebook: https://github.com/giswqs/leafmap/blob/master/examples/notebooks/54_plot_raster.ipynb
# pyvista-xarray: https://github.com/pyvista/pyvista-xarray

# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/giswqs/leafmap/blob/master/examples/notebooks/54_plot_raster.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://gishub.org/leafmap-binder)
#
# Uncomment the following line to install [leafmap](https://leafmap.org) if needed.

# %%
# !pip install -U leafmap

# %%
import os
import leafmap

# %% [markdown]
# Download a sample dataset.

# %%
url = 'https://github.com/giswqs/data/raw/main/raster/srtm90.tif'

# %%
image = 'srtm90.tif'
if not os.path.exists(image):
    leafmap.download_file(url, image)
# Out:
# Downloading...
# From: https://github.com/giswqs/data/raw/main/raster/srtm90.tif
# To: /home/yoviajo/Documentos/lab/geom/90/srtm90.tif
# 100%|██████████| 15.2M/15.2M [00:04<00:00, 3.69MB/s]

# %% [markdown]
# Plot the raster image in 2D.

# %%
leafmap.plot_raster(image, cmap='terrain', figsize=(15, 10))

# %% [markdown]
# ![](https://i.imgur.com/oDoivba.png)

# %% [markdown]
# Plot the raster image in 3D.

# %%
leafmap.plot_raster_3d('srtm90.tif', factor=2, cmap='terrain', background='gray')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ![](https://i.imgur.com/UQDbV2G.gif)

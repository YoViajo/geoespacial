# %% [markdown]
# Demostración de lectura de conjunto de datos masivo en formato Parquet

# %%
import geopandas

# %%
geopandas.read_parquet("/home/yoviajo/Documentos/lab/geom/python/86/geodat/nz-building-outlines.parquet")
# Out:
#          building_id                        name          use  \
# 0            2292028                                  Unknown
# 1            2292051                                  Unknown
# 2            2292290                                  Unknown
# 3            2292353                                  Unknown
# 4            2292407                                  Unknown
# ...              ...                         ...          ...
# 3320493      4679102           PAK'nSAVE Tauriko  Supermarket
# 3320494      4679107                                  Unknown
# 3320495      4679108  New World Metro Shore City  Supermarket
# 3320496      4679155     New World Durham Street  Supermarket
# 3320497      4679162           PAK'nSAVE Tamatea  Supermarket
#
#               suburb_locality     town_city territorial_authority  \
# 0                      Akitio                    Tararua District
# 1                      Marton        Marton   Rangitikei District
# ...

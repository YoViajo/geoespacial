# %% [markdown]
# Ref: https://geocompr.github.io/py/09-mapping.html
# Making maps with Python

# %% [markdown]
# Introducción

# %%
import matplotlib as mpl
import geopandas as gpd
bo = gpd.read_file("/home/yoviajo/Documentos/lab/geom/geodat/vector/bo_lim_dpto.gpkg")

# %% [markdown]
# Mapas estáticos

# %%
bo.plot(color="grey");
bo.plot(color="none", edgecolor="blue");
bo.plot(color="grey", edgecolor="blue");

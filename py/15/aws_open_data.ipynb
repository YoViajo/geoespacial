# %% [markdown]
# Ref: https://github.com/giswqs/aws-open-data-geo
# aws-open-data-geo
#
# The AWS Open Data program hosts a lot of publicly available geospatial datasets. This repo compiles the list of all geospatial datasets on AWS as a CSV file and as a JSON file, making it easier to find and use them programmatically. The list is updated daily.

# %%
import pandas as pd

# %%
url = 'https://github.com/giswqs/aws-open-data-geo/raw/master/aws_geo_datasets.tsv'
df = pd.read_csv(url, sep='\t')
df.head()
# Out:
#                                                 Name  \
# 0           10m Annual Land Use Land Cover (9-class)
# 1  2021 Amazon Last Mile Routing Research Challen...
# 2              A2D2: Audi Autonomous Driving Dataset
# 3  ARPA-E PERFORM Forecast data - ARPA-E PERFORM ...
# 4  ARPA-E PERFORM Forecast data - Forecasts and A...
#
#                                          Description  \
# 0           10m Annual Land Use Land Cover (9-class)
# 1  Dataset including training and testing data Fo...
# 2                                    http://a2d2audi
# 3                       ARPA-E PERFORM Forecast data
# 4  Forecasts and Actuals for The Electric Reliabi...
#
#                                            ARN        Region       Type  \
# 0              arn:aws:s3:::io-10m-annual-lulc     us-west-2  S3 Bucket
# 1     arn:aws:s3:::amazon-last-mile-challenges     us-west-2  S3 Bucket
# 2  arn:aws:s3:::aev-autonomous-driving-dataset  eu-central-1  S3 Bucket
# 3                 arn:aws:s3:::arpa-e-perform/     us-west-2  S3 Bucket
# 4           arn:aws:s3:::arpa-e-perform/ERCOT/     us-west-2  S3 Bucket
#
#   RequesterPays Explore                                      Documentation  \
# 0           NaN     NaN      https://www.impactobservatory.com/global_maps
# 1           NaN     NaN  https://github.com/MIT-CAVE/rc-cli/blob/main/t...
# 2           NaN     NaN                                   http://a2d2.audi
# 3           NaN     NaN  https://github.com/PERFORM-Forecasts/documenta...
# 4           NaN     NaN  https://github.com/PERFORM-Forecasts/documenta...
#
#                                              Contact  \
# 0                        hello@impactobservatory.com
# 1             lastmile-research-challenge@amazon.com
# 2                          aevdrivingdataset@audi.de
# 3  https://github.com/openEDI/PERFORM-Forecasts/d...
# 4  https://github.com/openEDI/PERFORM-Forecasts/d...
#
#                                            ManagedBy  \
# 0  [Impact Observatory](https://www.impactobserva...
# 1                  [Amazon](https://www.amazon.com/)
# 2                       [Audi AG](http://a2d2.audi/)
# 3  [National Renewable Energy Laboratory](https:/...
# 4  [National Renewable Energy Laboratory](https:/...
#
#                                      UpdateFrequency  \
# 0                              Annually each January
# 1                                               None
# 2  The dataset may be updated with additional or ...
# 3                                          As needed
# 4                                          As needed
#
#                                              License  \
# 0  [CC BY 4.0](https://creativecommons.org/licens...
# 1  Copyright Amazon.com, Inc. or its affiliates. ...
# 2    https://creativecommons.org/licenses/by-nd/4.0/
# 3  Creative Commons Attribution 3.0 United States...
# 4  Creative Commons Attribution 3.0 United States...
#
#                                                 Tags Host AccountRequired
# 0  ['earth observation', 'environmental', 'geospa...  NaN             NaN
# 1  ['transportation', 'machine learning', 'deep l...  NaN             NaN
# 2  ['autonomous vehicles', 'deep learning', 'comp...  NaN             NaN
# 3  ['aws-pds', 'energy', 'environmental', 'sustai...  NaN             NaN
# 4  ['aws-pds', 'energy', 'environmental', 'sustai...  NaN             NaN
